# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
colors = np.array(['blue','green','red','cyan','magenta','yellow','black'])
marker_size = 75
marker_alpha = 0.25
directory = "../Data/3CentroidTest/"

# %%
df_points = pd.read_csv(directory+"3CentroidTest_Points.csv")
df_points = df_points.drop(['Unnamed: 0', 'index'], axis=1)
df_points.head()
# Out:
#           0          1  Index
# 0 -0.197217   8.255923      1
# 1  1.184272   7.080087      2
# 2  1.131134   8.758666      3
# 3  0.563816   9.643193      4
# 4 -0.234380  10.334680      5

# %%
df_1NORM_ASSIGNMENTS =  pd.read_csv(directory+"Assignment_1_NORM.csv")
df_1NORM_CENTROIDS =  pd.read_csv(directory+"Centroid_1_NORM.csv")

# %%
df_1NORM_ASSIGNMENTS = df_1NORM_ASSIGNMENTS.drop('Unnamed: 0',axis=1)
df_1NORM_CENTROIDS =df_1NORM_CENTROIDS.drop('Unnamed: 0',axis=1)

# %%
df_1NORM_CENTROIDS['iteration']=df_1NORM_CENTROIDS['iteration'].astype('int')
df_1NORM_CENTROIDS['index']= df_1NORM_CENTROIDS['index'].astype('int')

# %%
df_1NORM_CENTROIDS['color'] = colors[df_1NORM_CENTROIDS['index']]

# %%
df_INF_NORM_ASSIGNMENTS =  pd.read_csv(directory+"Assignment_INF_NORM.csv")
df_INF_CENTROIDS =  pd.read_csv(directory+"Centroid_INF_NORM.csv")

# %%
df_INF_NORM_ASSIGNMENTS.drop('Unnamed: 0',axis=1)
df_INF_CENTROIDS.drop('Unnamed: 0',axis=1).head()
# Out:
#    iteration  index       x_1       x_2
# 0        0.0    1.0 -4.352713  6.626055
# 1        0.0    2.0 -4.925280  5.869827
# 2        0.0    3.0 -4.355812  7.134931
# 3        1.0    1.0 -4.352713  6.626055
# 4        1.0    2.0 -4.925280  5.869827

# %%
df_1NORM_MERGE = df_points.merge(df_1NORM_ASSIGNMENTS,left_on = ['Index'],right_on=['P_i'])
df_1NORM_MERGE.head()
# Out:
#           0         1  Index  iteration  P_i  C_j
# 0 -0.197217  8.255923      1          0    1    1
# 1 -0.197217  8.255923      1          1    1    2
# 2 -0.197217  8.255923      1          2    1    2
# 3 -0.197217  8.255923      1          3    1    2
# 4 -0.197217  8.255923      1          4    1    2

# %%
df_1NORM_MERGE['color'] = colors[df_1NORM_MERGE['C_j']]

# %%
df_1Norm_0 = df_1NORM_MERGE[df_1NORM_MERGE['iteration']==0]
df_1Norm_Centroid_0 = df_1NORM_CENTROIDS[df_1NORM_CENTROIDS['iteration']==0]
df_1Norm_Centroid_0.head()
# Out:
#    iteration  index       x_1       x_2  color
# 0          0      1 -4.162395  6.741227  green
# 1          0      2 -3.852334  6.665058    red
# 2          0      3 -4.114550  6.701516   cyan

# %% [markdown]
# ## 1 Norm Plots

# %%
df_1Norm_0 = df_1NORM_MERGE[df_1NORM_MERGE['iteration']==0]
df_1Norm_Centroid_0 = df_1NORM_CENTROIDS[df_1NORM_CENTROIDS['iteration']==0]
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(x=df_1Norm_0['0'],y=df_1Norm_0['1'],color=df_1Norm_0.color.values)
ax1.scatter(x=df_1Norm_Centroid_0.x_1,y=df_1Norm_Centroid_0.x_2,c=df_1Norm_Centroid_0.color.values, edgecolor='black',linewidths=3, s=marker_size)

# %%
df_1Norm_0 = df_1NORM_MERGE[df_1NORM_MERGE['iteration']==1]
df_1Norm_Centroid_0 = df_1NORM_CENTROIDS[df_1NORM_CENTROIDS['iteration']==1]
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(x=df_1Norm_0['0'],y=df_1Norm_0['1'],color=df_1Norm_0.color.values)
ax1.scatter(x=df_1Norm_Centroid_0.x_1,y=df_1Norm_Centroid_0.x_2,c=df_1Norm_Centroid_0.color.values, edgecolor='black',linewidths=3, s=marker_size)

# %%
df_1Norm_0 = df_1NORM_MERGE[df_1NORM_MERGE['iteration']==2]
df_1Norm_Centroid_0 = df_1NORM_CENTROIDS[df_1NORM_CENTROIDS['iteration']==2]
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(x=df_1Norm_0['0'],y=df_1Norm_0['1'],color=df_1Norm_0.color.values)
ax1.scatter(x=df_1Norm_Centroid_0.x_1,y=df_1Norm_Centroid_0.x_2,c=df_1Norm_Centroid_0.color.values, edgecolor='black',linewidths=3, s=marker_size)

# %%
df_1Norm_0 = df_1NORM_MERGE[df_1NORM_MERGE['iteration']==3]
df_1Norm_Centroid_0 = df_1NORM_CENTROIDS[df_1NORM_CENTROIDS['iteration']==3]
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(x=df_1Norm_0['0'],y=df_1Norm_0['1'],color=df_1Norm_0.color.values)

ax1.scatter(x=df_1Norm_Centroid_0.x_1,y=df_1Norm_Centroid_0.x_2,c=df_1Norm_Centroid_0.color.values, edgecolor='black',linewidths=3, s=marker_size)

# %%
df_1Norm_0 = df_1NORM_MERGE[df_1NORM_MERGE['iteration']==4]
df_1Norm_Centroid_0 = df_1NORM_CENTROIDS[df_1NORM_CENTROIDS['iteration']==4]
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(x=df_1Norm_0['0'],y=df_1Norm_0['1'],color=df_1Norm_0.color.values)
ax1.scatter(x=df_1Norm_Centroid_0.x_1,y=df_1Norm_Centroid_0.x_2,c=df_1Norm_Centroid_0.color.values, edgecolor='black',linewidths=3, s=marker_size)

# %%
df_1Norm_0 = df_1NORM_MERGE[df_1NORM_MERGE['iteration']==5]
df_1Norm_Centroid_0 = df_1NORM_CENTROIDS[df_1NORM_CENTROIDS['iteration']==5]
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(x=df_1Norm_0['0'],y=df_1Norm_0['1'],color=df_1Norm_0.color.values)
ax1.scatter(x=df_1Norm_Centroid_0.x_1,y=df_1Norm_Centroid_0.x_2,c=df_1Norm_Centroid_0.color.values, edgecolor='black',linewidths=3, s=marker_size)

# %%
df_1Norm_0 = df_1NORM_MERGE[df_1NORM_MERGE['iteration']==6]
df_1Norm_Centroid_0 = df_1NORM_CENTROIDS[df_1NORM_CENTROIDS['iteration']==6]
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(x=df_1Norm_0['0'],y=df_1Norm_0['1'],color=df_1Norm_0.color.values)
ax1.scatter(x=df_1Norm_Centroid_0.x_1,y=df_1Norm_Centroid_0.x_2,c=df_1Norm_Centroid_0.color.values, edgecolor='black',linewidths=3, s=marker_size)
